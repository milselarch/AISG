# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /home/milselarch/projects/AISG/venv/lib/python3.9/site-packages (1.9.0)
# Requirement already satisfied: typing-extensions in /home/milselarch/projects/AISG/venv/lib/python3.9/site-packages (from torch) (3.7.4.3)

# %%
import os
import matplotlib.pyplot as plt
import model
import torch

from constants import model_params, base_data_path
from IPython.display import Image 
from matplotlib.pyplot import imshow
from utils import *
# Out:
# no display found. Using non-interactive Agg backend
# No module named 'foundations'

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# see issue #152
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# Directory from which we read the data
mode = "unlabeled"  # real, fake, or unlabeled

# Convert files to flac
# convert_to_flac(os.path.join(data_dir,mode))
dirpath = '../datasets/train/audios-mp3'
filenames = os.listdir(dirpath)
# filenames = [f'{dirpath}/{filename}' for filename in filenames]
filenames = filenames[:2]
print(filenames)
# Out:
# ['0050faba196c967a.mp3', '0001986a7d172fe0.mp3']

# %%
print(dirpath)
# print(os.path.join(filenames[0], dirpath, mode))
processed_data = preprocess_from_filenames(
    filenames=filenames, dirpath=dirpath, mode='unlabeled',
    use_parallel=True
)
# Out:
# ../datasets/train/audios-mp3
# 100%|███████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 17.29it/s]
# /home/milselarch/projects/AISG/venv/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# /home/milselarch/projects/AISG/venv/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
model_params
# Out:
# {'num_freq_bin': 240,
#  'num_conv_blocks': 8,
#  'num_conv_filters': 32,
#  'spatial_dropout_fraction': 0.05,
#  'num_dense_layers': 1,
#  'num_dense_neurons': 50,
#  'dense_dropout': 0,
#  'learning_rate': 0.0001,
#  'epochs': 1,
#  'batch_size': 156,
#  'residual_con': 2,
#  'use_default': True,
#  'model_save_dir': 'fitted_objects'}

# %%
# %matplotlib inline
image_path = 'visualize_inference_spectrogram.png'
plot_spectrogram(
    processed_data[0],
    path=image_path
)
pil_img = Image(filename=image_path)
display(pil_img)

# %%
print(model_params)
discriminator = model.Discriminator(
    num_freq_bin=model_params['num_freq_bin'],
    init_neurons=model_params['num_conv_filters'],
    num_conv_blocks=model_params['num_conv_blocks'],
    residual_con=model_params['residual_con'],
    num_dense_neurons=model_params['num_dense_neurons'],
    dense_dropout=model_params['dense_dropout'],
    num_dense_layers=model_params['num_dense_layers'],
)
# Out:
# {'num_freq_bin': 240, 'num_conv_blocks': 8, 'num_conv_filters': 32, 'spatial_dropout_fraction': 0.05, 'num_dense_layers': 1, 'num_dense_neurons': 50, 'dense_dropout': 0, 'learning_rate': 0.0001, 'epochs': 1, 'batch_size': 156, 'residual_con': 2, 'use_default': True, 'model_save_dir': 'fitted_objects'}
# CONV LAYER 0 3
# Sequential(
#   (0): Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 1 3
# Sequential(
#   (0): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 2 3
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 2 3
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 3 3
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 3 3
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 4 3
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 4 3
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 5 3
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 5 3
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 6 3
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 6 3
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 7 3
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 7 3
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 0 5
# Sequential(
#   (0): Conv1d(240, 32, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 1 5
# Sequential(
#   (0): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 2 5
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 2 5
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 3 5
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 3 5
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 4 5
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 4 5
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 5 5
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 5 5
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 6 5
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 6 5
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 7 5
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 7 5
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 0 7
# Sequential(
#   (0): Conv1d(240, 32, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 1 7
# Sequential(
#   (0): Conv1d(32, 64, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV LAYER 2 7
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 2 7
# Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 3 7
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 3 7
# Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 4 7
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 4 7
# Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 5 7
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 5 7
# Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 6 7
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 6 7
# Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# CONV LAYER 7 7
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# RES CONV LAYER 7 7
# Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
discriminator.res_convnet_3_layers
# Out:
# {0: None,
#  1: None,
#  2: Sequential(
#    (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  3: Sequential(
#    (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  4: Sequential(
#    (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  5: Sequential(
#    (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  6: Sequential(
#    (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  7: Sequential(
#    (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#    (1): Linear(in_features=1, out_features=1, bias=True)
#  )}

# %%
# print(processed_data[0])

input_batch = processed_data[0][:model_params['batch_size']]
pad_batch = get_zero_pad(input_batch)
keras_batch_x = pad_batch.reshape((-1, 1, hparams.num_mels))
batch_x = torch.tensor(keras_batch_x).permute(0, 2, 1)
inputs = batch_x

print('KERAS BATCH SIZE')
print(keras_batch_x.shape)
print('')

print(processed_data[0].shape)
print(input_batch.shape)
print(pad_batch.shape)
print(batch_x.shape)
print(inputs.shape)
# print(inputs)

# pred = audioNet(inputs)
conv_batch = discriminator.convnet_3_layers[0]
start_conv = discriminator.convnet_3_layers[0][0]
linear = discriminator.convnet_3_layers[0][1]
relu = discriminator.convnet_3_layers[0][2]

start_conv_1 = discriminator.convnet_3_layers[1][0]
# linear_1 = discriminator.convnet_3_layers[1][1]
# relu_1 = discriminator.convnet_3_layers[1][2]
conv_batch_1 = discriminator.convnet_3_layers[1]
conv_batch_2 = discriminator.convnet_3_layers[2]
res_conv_batch_2 = discriminator.res_convnet_3_layers[2]

print(conv_batch_1)

print(start_conv)
print(linear)
conv_pred = conv_batch(inputs)
conv_pred_1 = conv_batch_1(conv_pred)
conv_pred_2 = conv_batch_2(conv_pred_1)

res_conv_pred_2 = res_conv_batch_2(conv_pred_1)
total = torch.add(conv_pred_2, res_conv_pred_2)

print('')
print('PRED PRODUCTION')
print(conv_pred_2.shape)
print(res_conv_pred_2.shape)
# print(total)

# print(pred)
video_input = processed_data[0][0]
final_pred = discriminator(inputs)
video_pred = discriminator(torch.from_numpy(video_input))

print('DENSE LAYERS', discriminator.num_dense_layers)
print('FPRED', video_pred.shape)
# Out:
# KERAS BATCH SIZE
# (156, 1, 240)
#
# (4452, 240)
# (156, 240)
# (156, 240)
# torch.Size([156, 240, 1])
# torch.Size([156, 240, 1])
# Sequential(
#   (0): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
# Linear(in_features=3, out_features=1, bias=True)
#
# PRED PRODUCTION
# torch.Size([156, 128, 1])
# torch.Size([156, 128, 1])
# KERNEL 3
# LAYER NO 0
# CONVNET LAYER Sequential(
#   (0): Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 32, 1])
# LAYER NO 1
# CONVNET LAYER Sequential(
#   (0): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 64, 1])
# LAYER NO 2
# CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 128, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 128, 1])
# CONV ADD SHAPE torch.Size([156, 128, 1])
# LAYER NO 3
# CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 192, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 192, 1])
# CONV ADD SHAPE torch.Size([156, 192, 1])
# LAYER NO 4
# CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 256, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 256, 1])
# CONV ADD SHAPE torch.Size([156, 256, 1])
# LAYER NO 5
# CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 320, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 320, 1])
# CONV ADD SHAPE torch.Size([156, 320, 1])
# LAYER NO 6
# CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 384, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 384, 1])
# CONV ADD SHAPE torch.Size([156, 384, 1])
# LAYER NO 7
# CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 448, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 448, 1])
# CONV ADD SHAPE torch.Size([156, 448, 1])
# POOL SHAPES
# torch.Size([156, 240, 1]) torch.Size([156, 448, 1])
# CONV DENSE torch.Size([156, 448])
# KERNEL 5
# LAYER NO 0
# CONVNET LAYER Sequential(
#   (0): Conv1d(240, 32, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 32, 1])
# LAYER NO 1
# CONVNET LAYER Sequential(
#   (0): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 64, 1])
# LAYER NO 2
# CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 128, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 128, 1])
# CONV ADD SHAPE torch.Size([156, 128, 1])
# LAYER NO 3
# CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 192, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 192, 1])
# CONV ADD SHAPE torch.Size([156, 192, 1])
# LAYER NO 4
# CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 256, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 256, 1])
# CONV ADD SHAPE torch.Size([156, 256, 1])
# LAYER NO 5
# CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 320, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 320, 1])
# CONV ADD SHAPE torch.Size([156, 320, 1])
# LAYER NO 6
# CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 384, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 384, 1])
# CONV ADD SHAPE torch.Size([156, 384, 1])
# LAYER NO 7
# CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(5,), stride=(1,), padding=(4,))
#   (1): Linear(in_features=5, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 448, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 448, 1])
# CONV ADD SHAPE torch.Size([156, 448, 1])
# POOL SHAPES
# torch.Size([156, 240, 1]) torch.Size([156, 448, 1])
# CONV DENSE torch.Size([156, 448])
# KERNEL 7
# LAYER NO 0
# CONVNET LAYER Sequential(
#   (0): Conv1d(240, 32, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 32, 1])
# LAYER NO 1
# CONVNET LAYER Sequential(
#   (0): Conv1d(32, 64, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 64, 1])
# LAYER NO 2
# CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 128, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 128, 1])
# CONV ADD SHAPE torch.Size([156, 128, 1])
# LAYER NO 3
# CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 192, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 192, 1])
# CONV ADD SHAPE torch.Size([156, 192, 1])
# LAYER NO 4
# CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 256, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 256, 1])
# CONV ADD SHAPE torch.Size([156, 256, 1])
# LAYER NO 5
# CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 320, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 320, 1])
# CONV ADD SHAPE torch.Size([156, 320, 1])
# LAYER NO 6
# CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 384, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 384, 1])
# CONV ADD SHAPE torch.Size([156, 384, 1])
# LAYER NO 7
# CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(7,), stride=(1,), padding=(6,))
#   (1): Linear(in_features=7, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 448, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 448, 1])
# CONV ADD SHAPE torch.Size([156, 448, 1])
# POOL SHAPES
# torch.Size([156, 240, 1]) torch.Size([156, 448, 1])
# CONV DENSE torch.Size([156, 448])
# PRE-CAT SHAPES [torch.Size([156, 448]), torch.Size([156, 448]), torch.Size([156, 448])]
# DENSE torch.Size([156, 1344])
# DENSE VAL 0 torch.Size([156, 50])
# KERNEL 3
# LAYER NO 0
# CONVNET LAYER Sequential(
#   (0): Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_361936/2585996294.py in <module>
#      50 # print(pred)
#      51 final_pred = discriminator(inputs)
# ---> 52 video_pred = discriminator(torch.from_numpy(processed_data[0][0]))
#      53
#      54 print('DENSE LAYERS', discriminator.num_dense_layers)
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/projects/AISG/fake-voice-torch/model.py in forward(self, image_inputs)
#     189                 convnet_layer = convnet_layers[layer_no]
#     190                 res_convnet_layer = res_convnet_layers[layer_no]
# --> 191                 print(f'CONVNET LAYER {convnet_layer}')
#     192                 sub_conv_output = convnet_layer(conv_output)
#     193                 print(f'CONV SHAPE {sub_conv_output.shape}')
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     296
#     297     def forward(self, input: Tensor) -> Tensor:
# --> 298         return self._conv_forward(input, self.weight, self.bias)
#     299
#     300
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     292                             weight, bias, self.stride,
#     293                             _single(0), self.dilation, self.groups)
# --> 294         return F.conv1d(input, weight, bias, self.stride,
#     295                         self.padding, self.dilation, self.groups)
#     296
#
# RuntimeError: Expected 3-dimensional input for 3-dimensional weight [32, 240, 3], but got 1-dimensional input of size [240] instead

# %%
test_pred = discriminator.test(inputs)

def pool(x):
    res_preds = x[1]
    torch_batch = x[0]
    
    print(torch_batch.shape)
    t_mask = torch.eq(torch.from_numpy(torch_batch), 0)
    t_mask = 1 - t_mask.float()
    print(t_mask.shape)

    t_mask = torch.all(t_mask, dim=-2, keepdim=True)
    print(t_mask.shape)

    t_steps_per_sample = torch.sum(t_mask, dim=2, keepdim=False)
    print(t_steps_per_sample.shape)
    t_target = torch.from_numpy(res_preds) * t_mask
    print(t_target.shape)
    t_total = torch.sum(t_target, dim=2, keepdim=False)
    print(t_total.shape)

    t_means = t_total / t_steps_per_sample
    print(t_means.shape)
    return t_means
# Out:
# LAYER NO 0
# CONVNET LAYER Sequential(
#   (0): Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 32, 1])
# LAYER NO 1
# CONVNET LAYER Sequential(
#   (0): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 64, 1])
# LAYER NO 2
# CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 128, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 128, 1])
# CONV ADD SHAPE torch.Size([156, 128, 1])
# LAYER NO 3
# CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 192, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(128, 192, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 192, 1])
# CONV ADD SHAPE torch.Size([156, 192, 1])
# LAYER NO 4
# CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 256, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(192, 256, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 256, 1])
# CONV ADD SHAPE torch.Size([156, 256, 1])
# LAYER NO 5
# CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 320, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(256, 320, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 320, 1])
# CONV ADD SHAPE torch.Size([156, 320, 1])
# LAYER NO 6
# CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 384, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(320, 384, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 384, 1])
# CONV ADD SHAPE torch.Size([156, 384, 1])
# LAYER NO 7
# CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
# CONV SHAPE torch.Size([156, 448, 1])
# RES CONVNET LAYER Sequential(
#   (0): Conv1d(384, 448, kernel_size=(1,), stride=(1,))
#   (1): Linear(in_features=1, out_features=1, bias=True)
# )
# RES CONV SHAPE torch.Size([156, 448, 1])
# CONV ADD SHAPE torch.Size([156, 448, 1])
# POOL SHAPES
# torch.Size([156, 240, 1]) torch.Size([156, 448, 1])

# %%
pool_pred = model.custom_pooling([inputs, test_pred])
c_pool_pred = pool([inputs.numpy(), test_pred.detach().numpy()])

print('INPUTS')
print(inputs.shape, test_pred.shape)
print('C_POOL')
print(pool_pred.shape)
print(c_pool_pred.shape)
# Out:
# (156, 240, 1)
# torch.Size([156, 240, 1])
# torch.Size([156, 1, 1])
# torch.Size([156, 1])
# torch.Size([156, 448, 1])
# torch.Size([156, 448])
# torch.Size([156, 448])
# INPUTS
# torch.Size([156, 240, 1]) torch.Size([156, 448, 1])
# C_POOL
# torch.Size([156, 448])
# torch.Size([156, 448])

# %%
discriminator.convnet_3_layers[0](batch_x)
# Out:
# tensor([[[-0.1298],
#          [-0.0432],
#          [-0.1156],
#          ...,
#          [-0.1455],
#          [-0.0831],
#          [-0.0623]],
#
#         [[-0.1298],
#          [-0.0432],
#          [-0.1156],
#          ...,
#          [-0.1455],
#          [-0.0831],
#          [-0.0623]],
#
#         [[-0.1298],
#          [-0.0432],
#          [-0.1156],
#          ...,
#          [-0.1455],
#          [-0.0831],
#          [-0.0623]],
#
#         ...,
#
#         [[-0.1288],
#          [-0.0431],
#          [-0.1148],
#          ...,
#          [-0.1469],
#          [-0.0828],
#          [-0.0629]],
#
#         [[-0.1298],
#          [-0.0432],
#          [-0.1156],
#          ...,
#          [-0.1455],
#          [-0.0831],
#          [-0.0623]],
#
#         [[-0.1298],
#          [-0.0432],
#          [-0.1156],
#          ...,
#          [-0.1455],
#          [-0.0831],
#          [-0.0623]]], grad_fn=<LeakyReluBackward0>)

# %%
discriminator.convnet_3_layers[0]
# Out:
# Sequential(
#   (0): Conv1d(240, 32, kernel_size=(3,), stride=(1,), padding=(2,))
#   (1): Linear(in_features=3, out_features=1, bias=True)
#   (2): LeakyReLU(negative_slope=0.3)
# )
