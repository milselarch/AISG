# %%
from IPython.display import display, HTML
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn.metrics
import sklearn

# %%
labels_df = pd.read_csv('../stats/all-labels.csv')
display(labels_df)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  both_fake
# 0     9a22372d22a52397.mp4      1         1.0        1.0          0          1
# 1     9bc4f1306bb8e2cd.mp4      1         1.0        1.0          0          1
# 2     88fe2a902a9d8cc7.mp4      1         1.0        1.0          0          1
# 3     1f3cbda142d0944a.mp4      1         1.0        1.0          0          1
# 4     63bed62257daccaf.mp4      1         1.0        1.0          0          1
# ...                    ...    ...         ...        ...        ...        ...
# 6938  f5c4bfb20068f129.mp4      0         0.0        0.0          0          0
# 6939  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0          0
# 6940  c3fc75289ae3b41e.mp4      0         0.0        0.0          0          0
# 6941  519e97d4c90aaa1c.mp4      0         0.0        0.0          0          0
# 6942  38cd7b295a5cfda5.mp4      0         0.0        0.0          0          0
#
# [6943 rows x 6 columns]

# %%
face_sync_df = pd.read_csv('stats/sync-vid-preds-211105-2210.csv')
display(face_sync_df)
# Out:
#                   filename  mean_pred  median_pred  1st_quartile_pred  \
# 0     9a22372d22a52397.mp4   0.564207     0.538990           0.367158
# 1     9bc4f1306bb8e2cd.mp4   0.542167     0.504413           0.370015
# 2     88fe2a902a9d8cc7.mp4   0.513700     0.464985           0.387646
# 3     1f3cbda142d0944a.mp4   0.488744     0.470903           0.333023
# 4     63bed62257daccaf.mp4   0.487096     0.415824           0.341504
# ...                    ...        ...          ...                ...
# 7389  f5c4bfb20068f129.mp4   0.625857     0.702673           0.294314
# 7390  b7b7b7f6db7f6e2e.mp4   0.765811     0.862065           0.660070
# 7391  c3fc75289ae3b41e.mp4   0.761405     0.817571           0.656039
# 7392  519e97d4c90aaa1c.mp4   0.590451     0.543361           0.416230
# 7393  38cd7b295a5cfda5.mp4   0.719195     0.795547           0.524008
#
#       3rd_quartile_pred  face_no
# 0              0.791909        0
# 1              0.713077        0
# 2              0.641136        0
# 3              0.609268        0
# 4              0.647832        0
# ...                 ...      ...
# 7389           0.906288        0
# 7390           0.965780        0
# 7391           0.933439        0
# 7392           0.837065        0
# 7393           0.934209        0
#
# [7394 rows x 6 columns]

# %%
face_sync_df = face_sync_df.groupby('filename', sort=False).agg(min)
sync_df = pd.merge(
    left=labels_df, right=face_sync_df, 
    left_on='filename', right_on='filename'
)
# print(np.unique(sync_df['face_no']))
display(sync_df)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  \
# 0     9a22372d22a52397.mp4      1         1.0        1.0          0
# 1     9bc4f1306bb8e2cd.mp4      1         1.0        1.0          0
# 2     88fe2a902a9d8cc7.mp4      1         1.0        1.0          0
# 3     1f3cbda142d0944a.mp4      1         1.0        1.0          0
# 4     63bed62257daccaf.mp4      1         1.0        1.0          0
# ...                    ...    ...         ...        ...        ...
# 7389  f5c4bfb20068f129.mp4      0         0.0        0.0          0
# 7390  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0
# 7391  c3fc75289ae3b41e.mp4      0         0.0        0.0          0
# 7392  519e97d4c90aaa1c.mp4      0         0.0        0.0          0
# 7393  38cd7b295a5cfda5.mp4      0         0.0        0.0          0
#
#       both_fake  mean_pred  median_pred  1st_quartile_pred  3rd_quartile_pred  \
# 0             1   0.564207     0.538990           0.367158           0.791909
# 1             1   0.542167     0.504413           0.370015           0.713077
# 2             1   0.513700     0.464985           0.387646           0.641136
# 3             1   0.488744     0.470903           0.333023           0.609268
# 4             1   0.487096     0.415824           0.341504           0.647832
# ...         ...        ...          ...                ...                ...
# 7389          0   0.625857     0.702673           0.294314           0.906288
# 7390          0   0.765811     0.862065           0.660070           0.965780
# 7391          0   0.761405     0.817571           0.656039           0.933439
# 7392          0   0.590451     0.543361           0.416230           0.837065
# 7393          0   0.719195     0.795547           0.524008           0.934209
#
#       face_no
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 7389        0
# 7390        0
# 7391        0
# 7392        0
# 7393        0
#
# [7394 rows x 11 columns]

# %%
preds = sync_df['median_pred']
plt.style.use('ggplot')
plt.figure(figsize=(12, 5))
plt.hist(preds, density=True, bins=30)  # density=False would make counts
# Out:
# (array([0.0470472 , 0.1254592 , 0.25614586, 0.26137333, 0.30319306,
#         0.29273813, 0.48092693, 0.59070373, 0.54888399, 0.58024879,
#         0.67434319, 0.78411999, 0.88866932, 1.04026586, 1.10822292,
#         1.17095252, 1.15527012, 1.30686665, 1.43755332, 1.45323572,
#         1.50028292, 1.67801678, 1.86620558, 1.73029145, 2.46736424,
#         2.70260024, 3.0057933 , 3.41876316, 3.61217943, 2.16417118]),
#  array([0.22384128, 0.24971324, 0.27558519, 0.30145715, 0.32732911,
#         0.35320107, 0.37907302, 0.40494498, 0.43081694, 0.4566889 ,
#         0.48256085, 0.50843281, 0.53430477, 0.56017673, 0.58604868,
#         0.61192064, 0.6377926 , 0.66366455, 0.68953651, 0.71540847,
#         0.74128043, 0.76715238, 0.79302434, 0.8188963 , 0.84476826,
#         0.87064021, 0.89651217, 0.92238413, 0.94825609, 0.97412804,
#         1.        ]),
#  <BarContainer object of 30 artists>)

# %%
rsync_df = sync_df[
    (sync_df['swap_fake'] == 1) |
    (sync_df['label'] == 0)
]
display(rsync_df)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  \
# 185   18351609de111566.mp4      1         0.0        0.0          1
# 186   5026338ed12800bc.mp4      1         0.0        0.0          1
# 187   5968740ef3396f0c.mp4      1         0.0        0.0          1
# 188   50e301013618719d.mp4      1         0.0        0.0          1
# 189   bc6dd15cfdfe6175.mp4      1         0.0        0.0          1
# ...                    ...    ...         ...        ...        ...
# 7389  f5c4bfb20068f129.mp4      0         0.0        0.0          0
# 7390  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0
# 7391  c3fc75289ae3b41e.mp4      0         0.0        0.0          0
# 7392  519e97d4c90aaa1c.mp4      0         0.0        0.0          0
# 7393  38cd7b295a5cfda5.mp4      0         0.0        0.0          0
#
#       both_fake  mean_pred  median_pred  1st_quartile_pred  3rd_quartile_pred  \
# 185           0   0.832199     0.966656           0.787735           0.999631
# 186           0   0.833936     0.947372           0.830766           0.998021
# 187           0   0.830931     0.957452           0.836071           0.996780
# 188           0   0.858643     0.956645           0.766065           0.997484
# 189           0   0.851412     0.961972           0.838287           0.998866
# ...         ...        ...          ...                ...                ...
# 7389          0   0.625857     0.702673           0.294314           0.906288
# 7390          0   0.765811     0.862065           0.660070           0.965780
# 7391          0   0.761405     0.817571           0.656039           0.933439
# 7392          0   0.590451     0.543361           0.416230           0.837065
# 7393          0   0.719195     0.795547           0.524008           0.934209
#
#       face_no
# 185         0
# 186         0
# 187         0
# 188         0
# 189         0
# ...       ...
# 7389        0
# 7390        0
# 7391        0
# 7392        0
# 7393        0
#
# [3590 rows x 11 columns]

# %%
r_preds, r_labels = rsync_df['median_pred'], rsync_df['label']
plt.style.use('ggplot')
plt.figure(figsize=(12, 5))
plt.plot(r_preds, r_labels)

# %%
fpr, tpr, _ = sklearn.metrics.roc_curve(r_labels, r_preds)
auc = sklearn.metrics.roc_auc_score(r_labels, r_preds)

plt.style.use('ggplot')
plt.figure(figsize=(12, 5))
plt.xlim([-0.02, 1.02])
plt.ylim([-0.05, 1.05])
plt.title("sync only prediction ROC. AUC="+str(round(auc, 10)))
plt.plot(fpr, tpr)

# %%
fpr, tpr, _ = sklearn.metrics.roc_curve(face_sync_df['label'], face_sync_df['median_pred'])
auc = sklearn.metrics.roc_auc_score(face_sync_df['label'], face_sync_df['median_pred'])

plt.style.use('ggplot')
plt.figure(figsize=(12, 5))
plt.xlim([-0.02, 1.02])
plt.ylim([-0.05, 1.05])
plt.title("sync on all prediction ROC. AUC="+str(round(auc, 10)))
plt.plot(fpr, tpr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/projects/AISG/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_630897/116139286.py in <module>
# ----> 1 fpr, tpr, _ = sklearn.metrics.roc_curve(face_sync_df['label'], face_sync_df['median_pred'])
#       2 auc = sklearn.metrics.roc_auc_score(face_sync_df['label'], face_sync_df['median_pred'])
#       3
#       4 plt.style.use('ggplot')
#       5 plt.figure(figsize=(12, 5))
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/projects/AISG/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'label'

# %%
for metric in ['median_pred', '1st_quartile_pred', '3rd_quartile_pred']:
    labels = rsync_df['label'].to_numpy()
    sync_preds = rsync_df[metric].to_numpy()
    fpr, tpr, _ = sklearn.metrics.roc_curve(labels, sync_preds)
    auc = sklearn.metrics.roc_auc_score(labels, sync_preds)

    plt.style.use('ggplot')
    plt.figure(figsize=(12, 5))
    plt.xlim([-0.02, 1.02])
    plt.ylim([-0.02, 1.02])
    plt.title(f"[{metric}] face prediction ROC. AUC="+str(round(auc, 3)))
    plt.plot(fpr, tpr)
