# %%
from IPython.display import display, HTML
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn.metrics
import sklearn
import ast

# %%
labels_df = pd.read_csv('../../stats/all-labels.csv')
display(labels_df)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  both_fake
# 0     9a22372d22a52397.mp4      1         1.0        1.0          0          1
# 1     9bc4f1306bb8e2cd.mp4      1         1.0        1.0          0          1
# 2     88fe2a902a9d8cc7.mp4      1         1.0        1.0          0          1
# 3     1f3cbda142d0944a.mp4      1         1.0        1.0          0          1
# 4     63bed62257daccaf.mp4      1         1.0        1.0          0          1
# ...                    ...    ...         ...        ...        ...        ...
# 6938  f5c4bfb20068f129.mp4      0         0.0        0.0          0          0
# 6939  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0          0
# 6940  c3fc75289ae3b41e.mp4      0         0.0        0.0          0          0
# 6941  519e97d4c90aaa1c.mp4      0         0.0        0.0          0          0
# 6942  38cd7b295a5cfda5.mp4      0         0.0        0.0          0          0
#
# [6943 rows x 6 columns]

# %%
def load_vid_preds(path):
    vid_preds = pd.read_csv(path)
    vid_preds = vid_preds.groupby('filename', sort=False, as_index=False).agg(min)
    vid_preds = pd.merge(
        left=labels_df, right=vid_preds, 
        left_on='filename', right_on='filename'
    )

    vid_preds['diff'] = vid_preds['mean_pred'] - vid_preds['median_pred']
    return vid_preds

def draw_roc(labels, preds):
    fpr, tpr, _ = sklearn.metrics.roc_curve(labels, preds)
    auc = sklearn.metrics.roc_auc_score(labels, preds)

    plt.style.use('ggplot')
    plt.figure(figsize=(12, 5))
    plt.xlim([-0.02, 1.02])
    plt.ylim([-0.05, 1.05])
    plt.title("CV regression ROC. AUC="+str(round(auc, 10)))
    plt.plot(fpr, tpr)

# %%
old_vid_preds = load_vid_preds('../stats/vid-dataset-211209-0226.csv')
display(old_vid_preds)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  \
# 0     18351609de111566.mp4      1         0.0        0.0          1
# 1     5026338ed12800bc.mp4      1         0.0        0.0          1
# 2     5968740ef3396f0c.mp4      1         0.0        0.0          1
# 3     50e301013618719d.mp4      1         0.0        0.0          1
# 4     bc6dd15cfdfe6175.mp4      1         0.0        0.0          1
# ...                    ...    ...         ...        ...        ...
# 3262  f5c4bfb20068f129.mp4      0         0.0        0.0          0
# 3263  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0
# 3264  c3fc75289ae3b41e.mp4      0         0.0        0.0          0
# 3265  519e97d4c90aaa1c.mp4      0         0.0        0.0          0
# 3266  38cd7b295a5cfda5.mp4      0         0.0        0.0          0
#
#       both_fake  mean_pred  median_pred  1st_quartile_pred  3rd_quartile_pred  \
# 0             0   0.886478     0.991882           0.877936           0.999761
# 1             0   0.771807     0.937751           0.705958           0.991937
# 2             0   0.908657     0.997838           0.957127           0.999761
# 3             0   0.689604     0.765472           0.535128           0.919209
# 4             0   0.798933     0.991416           0.705039           0.999836
# ...         ...        ...          ...                ...                ...
# 3262          0   0.322102     0.280690           0.135136           0.444732
# 3263          0   0.019183     0.006369           0.001618           0.020698
# 3264          0   0.056983     0.028271           0.006577           0.064418
# 3265          0   0.155874     0.104358           0.042252           0.214259
# 3266          0   0.024627     0.005802           0.001694           0.022475
#
#       std_pred  max_pred  min_pred  face_no      diff
# 0     0.213244  1.000000  0.180236        0 -0.105404
# 1     0.306803  1.000000  0.004848        0 -0.165944
# 2     0.197435  1.000000  0.030951        0 -0.089181
# 3     0.280081  0.999999  0.059797        0 -0.075868
# 4     0.306610  1.000000  0.025240        0 -0.192483
# ...        ...       ...       ...      ...       ...
# 3262  0.228058  0.986776  0.010469        0  0.041412
# 3263  0.034796  0.281572  0.000011        0  0.012814
# 3264  0.086561  0.548783  0.000074        0  0.028712
# 3265  0.175576  0.744065  0.000468        0  0.051515
# 3266  0.059143  0.483091  0.000001        0  0.018825
#
# [3267 rows x 15 columns]

# %%
train_files = open('../saves/checkpoints/211207-0123/train.txt').read()
train_files = ast.literal_eval(train_files)
print('train files:', len(train_files), train_files[:10])

test_files = open('../saves/checkpoints/211207-0123/test.txt').read()
test_files = ast.literal_eval(test_files)
print('test files:', len(test_files), test_files[:10])
# Out:
# train files: 2295 ['c59d2549456ad02a.mp4', '56d59930ddf61239.mp4', '8a4caf49711d8edf.mp4', 'f88e40b475cd6a70.mp4', '1a81b12442a68f4c.mp4', 'b2bd5f005134dda4.mp4', '8995bd37e6aeed6a.mp4', '91fff341619c8124.mp4', '326b8d65f8678680.mp4', 'df234b6a4267dad2.mp4']
# test files: 256 ['1c56956bc6540dd9.mp4', '6cf1650746f6a984.mp4', '3a80a52b6017096c.mp4', '519e97d4c90aaa1c.mp4', '2811815d3da7463d.mp4', '865683a96c834074.mp4', 'e304f9060ca59b48.mp4', 'c2fd2b49874c8d4a.mp4', 'e7c1248f1566506d.mp4', '7b00b4246abeba8b.mp4']

# %%
sub_vid_preds = old_vid_preds[
    old_vid_preds['filename'].isin(test_files)
]
# print(vid_preds)
sync_preds = sub_vid_preds['median_pred']
sync_labels = sub_vid_preds['swap_fake']
draw_roc(sync_labels, sync_preds)
# Out:
# /home/milselarch/projects/aisg_venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:949: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn("No positive samples in y_true, "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_647721/964795356.py in <module>
#       4 sync_preds = sub_vid_preds['median_pred']
#       5 sync_labels = sub_vid_preds['swap_fake']
# ----> 6 draw_roc(sync_labels, sync_preds)
#
# /tmp/ipykernel_647721/4169080804.py in draw_roc(labels, preds)
#      12 def draw_roc(labels, preds):
#      13     fpr, tpr, _ = sklearn.metrics.roc_curve(labels, preds)
# ---> 14     auc = sklearn.metrics.roc_auc_score(labels, preds)
#      15
#      16     plt.style.use('ggplot')
#
# ~/projects/aisg_venv/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/projects/aisg_venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     540         labels = np.unique(y_true)
#     541         y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 542         return _average_binary_score(partial(_binary_roc_auc_score,
#     543                                              max_fpr=max_fpr),
#     544                                      y_true, y_score, average,
#
# ~/projects/aisg_venv/lib/python3.9/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/projects/aisg_venv/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     325     """Binary roc auc score."""
#     326     if len(np.unique(y_true)) != 2:
# --> 327         raise ValueError("Only one class present in y_true. ROC AUC score "
#     328                          "is not defined in that case.")
#     329
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
new_vid_preds = load_vid_preds('../stats/vid-dataset-211210-0121.csv')
display(old_vid_preds)
# Out:
#                   filename  label  audio_fake  face_fake  swap_fake  \
# 0     18351609de111566.mp4      1         0.0        0.0          1
# 1     5026338ed12800bc.mp4      1         0.0        0.0          1
# 2     5968740ef3396f0c.mp4      1         0.0        0.0          1
# 3     50e301013618719d.mp4      1         0.0        0.0          1
# 4     bc6dd15cfdfe6175.mp4      1         0.0        0.0          1
# ...                    ...    ...         ...        ...        ...
# 3262  f5c4bfb20068f129.mp4      0         0.0        0.0          0
# 3263  b7b7b7f6db7f6e2e.mp4      0         0.0        0.0          0
# 3264  c3fc75289ae3b41e.mp4      0         0.0        0.0          0
# 3265  519e97d4c90aaa1c.mp4      0         0.0        0.0          0
# 3266  38cd7b295a5cfda5.mp4      0         0.0        0.0          0
#
#       both_fake  mean_pred  median_pred  1st_quartile_pred  3rd_quartile_pred  \
# 0             0   0.886478     0.991882           0.877936           0.999761
# 1             0   0.771807     0.937751           0.705958           0.991937
# 2             0   0.908657     0.997838           0.957127           0.999761
# 3             0   0.689604     0.765472           0.535128           0.919209
# 4             0   0.798933     0.991416           0.705039           0.999836
# ...         ...        ...          ...                ...                ...
# 3262          0   0.322102     0.280690           0.135136           0.444732
# 3263          0   0.019183     0.006369           0.001618           0.020698
# 3264          0   0.056983     0.028271           0.006577           0.064418
# 3265          0   0.155874     0.104358           0.042252           0.214259
# 3266          0   0.024627     0.005802           0.001694           0.022475
#
#       std_pred  max_pred  min_pred  face_no      diff
# 0     0.213244  1.000000  0.180236        0 -0.105404
# 1     0.306803  1.000000  0.004848        0 -0.165944
# 2     0.197435  1.000000  0.030951        0 -0.089181
# 3     0.280081  0.999999  0.059797        0 -0.075868
# 4     0.306610  1.000000  0.025240        0 -0.192483
# ...        ...       ...       ...      ...       ...
# 3262  0.228058  0.986776  0.010469        0  0.041412
# 3263  0.034796  0.281572  0.000011        0  0.012814
# 3264  0.086561  0.548783  0.000074        0  0.028712
# 3265  0.175576  0.744065  0.000468        0  0.051515
# 3266  0.059143  0.483091  0.000001        0  0.018825
#
# [3267 rows x 15 columns]

# %%
sync_preds = new_vid_preds['median_pred']
sync_labels = new_vid_preds['swap_fake']
draw_roc(sync_labels, sync_preds)
